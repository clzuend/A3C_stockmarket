# %%
# %run -i ./train.py --game=market --processes=16 --save_freq=100000 --market_data='../../ENV/NYQ/' --market_data_index='../../ENV/NYQ_index.csv' --verbose_learner=0 --outname='LSTM60'
# Out:
# /Users/czuend/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
#  81553> Learning process
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
#  81553> Setting weights in dict
# Frames:      120; Policy-Loss:  -1.160089; Avg:  -0.356419 --- Value-Loss:   0.296048; Avg:   0.125515 --- Entropy: -0.064805; Avg: -0.013519 --- Advantage: 0.345146; Avg: 0.345948 --- V-value; Min:  0.045; Max:  0.121; Avg:  0.083
#  81553> Updating weights in dict
# ...
