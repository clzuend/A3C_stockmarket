# %%
# %run -i ./train.py --game=market --processes=4 --save_freq=10000
# Out:
# /Users/czuend/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
#  39010> Learning process
#
#  39010> Setting weights in dict
# Frames:      120; Policy-Loss:  -0.476107; Avg:  -0.145312 --- Value-Loss:   0.128157; Avg:   0.105147 --- Entropy: -0.028236; Avg: 0.000681 --- Advantage: 0.342522; Avg: 0.343325 --- V-value; Min:  0.099; Max:  0.137; Avg:  0.1150
#  39010> Updating weights in dict
# ...
